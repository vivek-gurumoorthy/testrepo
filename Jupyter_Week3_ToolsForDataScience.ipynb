# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Vivek Gurumoorthy**
# Pharmaceutical Data Scientist

# %% [markdown]
# *I am interested in Data Science because of the prevalence of data in healthcare. The tremendous amount of data in the pharmaceutical industry creates a need for data-minded clinicians.*

# %% [markdown]
# ### Execute a mathematical operation using variables and display the output

# %%
one = 1
two = 2
three = one + two
print(three)
# Out:
# 3

# %% [markdown]
# **1. Table**
#
# |Sample_Header1|Sample_Header|
# |--------------|-------------|
# |cell1|cell2|
#
# **2. Bulleted List**
# - List_item1
# - List_item2
# - List_item3
#
# **3. Image**
#
# ![a62164195321e72c4c496b1d7bbce505d8-05-manning3.rsquare.w700.webp](attachment:a62164195321e72c4c496b1d7bbce505d8-05-manning3.rsquare.w700.webp)
